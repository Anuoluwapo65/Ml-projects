# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.columns= df.columns.str.lower().str.replace(" ", "_")
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df.dtypes =="object"
# Out:
# make                  True
# model                 True
# year                 False
# engine_fuel_type      True
# engine_hp            False
# engine_cylinders     False
# transmission_type     True
# driven_wheels         True
# number_of_doors      False
# market_category       True
# vehicle_size          True
# vehicle_style         True
# highway_mpg          False
# city_mpg             False
# popularity           False
# msrp                 False
# dtype: bool

# %%
strings = list(df.dtypes[df.dtypes == "object"].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(" ", "_")

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
## Exploratory Data Analysis

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
   for col in df.columns:
       print(df[col].unique()[:5])
       print(df[col].nunique())
       print()
# Out:
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
#
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
#
# [2011 2012 2013 1992 1993]
# 28
#
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
#
# [335. 300. 230. 320. 172.]
# 356
#
# [ 6.  4.  5.  8. 12.]
# 9
#
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# [ 2.  4.  3. nan]
# 3
#
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
#
# ['compact' 'midsize' 'large']
# 3
#
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
#
# [26 28 27 25 24]
# 59
#
# [19 20 18 17 16]
# 69
#
# [3916 3105  819  617 1013]
# 48
#
# [46135 40650 36350 29450 34500]
# 6049

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
strings = list(df.dtypes [df.dtypes == "object"].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(" ", "_")

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df.msrp[df.msrp < 10000], bins = 50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
np.log([1,10, 100, 10000])
# Out:
# array([0.        , 2.30258509, 4.60517019, 9.21034037])

# %%
price_exp = np.log1p([1, 10, 1000, 10000])
price_exp
# Out:
# array([0.69314718, 2.39789527, 6.90875478, 9.21044037])

# %%
price_exp = np.log1p(df.msrp)
price_exp
# Out:
# 0        10.739349
# 1        10.612779
# 2        10.500977
# 3        10.290483
# 4        10.448744
#            ...
# 11909    10.739024
# 11910    10.945018
# 11911    10.832122
# 11912    10.838031
# 11913    10.274913
# Name: msrp, Length: 11914, dtype: float64

# %%
sns.histplot(price_exp, bins = 50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
## setting up validation models

# %%
n =  len(df)

# %%
n_test = int( n * 0.2)
n_val = int(n * 0.2)
n_train = n - n_test - n_val

# %%
n_test
# Out:
# 2382

# %%
n_val
# Out:
# 2382

# %%
n_train
# Out:
# 7150

# %%
n_train, n_test, n_val
# Out:
# (7150, 2382, 2382)

# %%
idx = np.arange(n)
np.random.shuffle(idx)
np.random.seed(4)

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_train:n_train+n_val:]]

# %%
len(df_train), len(df_test), len(df_val)
# Out:
# (7150, 2382, 2382)

# %%
df_train
# Out:
#              make               model  year                engine_fuel_type  \
# 7473   volkswagen              passat  2016                regular_unleaded
# 1455      bentley              arnage  2008     premium_unleaded_(required)
# 10413  volkswagen              tiguan  2015  premium_unleaded_(recommended)
# 2769    chevrolet            colorado  2012                regular_unleaded
# 6930        tesla             model_s  2016                        electric
# ...           ...                 ...   ...                             ...
# 3720         ford        e-series_van  2012        flex-fuel_(unleaded/e85)
# 10167      toyota              tacoma  2015                regular_unleaded
# 6963      pontiac             montana  2005                regular_unleaded
# 1810   volkswagen  beetle_convertible  2014  premium_unleaded_(recommended)
# 3018    chevrolet            corvette  2017  premium_unleaded_(recommended)
#
# ...

# %%
df_val
# Out:
#              make            model  year                engine_fuel_type  \
# 7876         audi               q7  2014     premium_unleaded_(required)
# 9134       toyota          sequoia  2017                regular_unleaded
# 6843      lincoln              mkc  2015                regular_unleaded
# 314        nissan             370z  2015     premium_unleaded_(required)
# 7678       toyota      prius_prime  2017                regular_unleaded
# ...           ...              ...   ...                             ...
# 11534         bmw               x6  2017     premium_unleaded_(required)
# 2421   volkswagen               cc  2017  premium_unleaded_(recommended)
# 2963    chevrolet          corsica  1996                regular_unleaded
# 8161        dodge  ram_pickup_1500  2008                regular_unleaded
# 1881   volkswagen           beetle  2015                          diesel
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_test
# Out:
#              make            model  year                engine_fuel_type  \
# 7876         audi               q7  2014     premium_unleaded_(required)
# 9134       toyota          sequoia  2017                regular_unleaded
# 6843      lincoln              mkc  2015                regular_unleaded
# 314        nissan             370z  2015     premium_unleaded_(required)
# 7678       toyota      prius_prime  2017                regular_unleaded
# ...           ...              ...   ...                             ...
# 11534         bmw               x6  2017     premium_unleaded_(required)
# 2421   volkswagen               cc  2017  premium_unleaded_(recommended)
# 2963    chevrolet          corsica  1996                regular_unleaded
# 8161        dodge  ram_pickup_1500  2008                regular_unleaded
# 1881   volkswagen           beetle  2015                          diesel
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train = df_train.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)

# %%
df_train
# Out:
#             make               model  year                engine_fuel_type  \
# 0     volkswagen              passat  2016                regular_unleaded
# 1        bentley              arnage  2008     premium_unleaded_(required)
# 2     volkswagen              tiguan  2015  premium_unleaded_(recommended)
# 3      chevrolet            colorado  2012                regular_unleaded
# 4          tesla             model_s  2016                        electric
# ...          ...                 ...   ...                             ...
# 7145        ford        e-series_van  2012        flex-fuel_(unleaded/e85)
# 7146      toyota              tacoma  2015                regular_unleaded
# 7147     pontiac             montana  2005                regular_unleaded
# 7148  volkswagen  beetle_convertible  2014  premium_unleaded_(recommended)
# 7149   chevrolet            corvette  2017  premium_unleaded_(recommended)
#
# ...

# %%
df_test
# Out:
#             make            model  year                engine_fuel_type  \
# 0           audi               q7  2014     premium_unleaded_(required)
# 1         toyota          sequoia  2017                regular_unleaded
# 2        lincoln              mkc  2015                regular_unleaded
# 3         nissan             370z  2015     premium_unleaded_(required)
# 4         toyota      prius_prime  2017                regular_unleaded
# ...          ...              ...   ...                             ...
# 2377         bmw               x6  2017     premium_unleaded_(required)
# 2378  volkswagen               cc  2017  premium_unleaded_(recommended)
# 2379   chevrolet          corsica  1996                regular_unleaded
# 2380       dodge  ram_pickup_1500  2008                regular_unleaded
# 2381  volkswagen           beetle  2015                          diesel
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_val
# Out:
#             make            model  year                engine_fuel_type  \
# 0           audi               q7  2014     premium_unleaded_(required)
# 1         toyota          sequoia  2017                regular_unleaded
# 2        lincoln              mkc  2015                regular_unleaded
# 3         nissan             370z  2015     premium_unleaded_(required)
# 4         toyota      prius_prime  2017                regular_unleaded
# ...          ...              ...   ...                             ...
# 2377         bmw               x6  2017     premium_unleaded_(required)
# 2378  volkswagen               cc  2017  premium_unleaded_(recommended)
# 2379   chevrolet          corsica  1996                regular_unleaded
# 2380       dodge  ram_pickup_1500  2008                regular_unleaded
# 2381  volkswagen           beetle  2015                          diesel
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
y_train = np.log1p(df_train.msrp.values)
y_test = np.log1p(df_test.msrp.values)
y_val = np.log1p(df_val.msrp.values)

# %%
del df_train["msrp"]
del df_test["msrp"]
del df_val["msrp"]

# %%
df_train
# Out:
#             make               model  year                engine_fuel_type  \
# 0     volkswagen              passat  2016                regular_unleaded
# 1        bentley              arnage  2008     premium_unleaded_(required)
# 2     volkswagen              tiguan  2015  premium_unleaded_(recommended)
# 3      chevrolet            colorado  2012                regular_unleaded
# 4          tesla             model_s  2016                        electric
# ...          ...                 ...   ...                             ...
# 7145        ford        e-series_van  2012        flex-fuel_(unleaded/e85)
# 7146      toyota              tacoma  2015                regular_unleaded
# 7147     pontiac             montana  2005                regular_unleaded
# 7148  volkswagen  beetle_convertible  2014  premium_unleaded_(recommended)
# 7149   chevrolet            corvette  2017  premium_unleaded_(recommended)
#
# ...

# %%
df_val
# Out:
#             make            model  year                engine_fuel_type  \
# 0           audi               q7  2014     premium_unleaded_(required)
# 1         toyota          sequoia  2017                regular_unleaded
# 2        lincoln              mkc  2015                regular_unleaded
# 3         nissan             370z  2015     premium_unleaded_(required)
# 4         toyota      prius_prime  2017                regular_unleaded
# ...          ...              ...   ...                             ...
# 2377         bmw               x6  2017     premium_unleaded_(required)
# 2378  volkswagen               cc  2017  premium_unleaded_(recommended)
# 2379   chevrolet          corsica  1996                regular_unleaded
# 2380       dodge  ram_pickup_1500  2008                regular_unleaded
# 2381  volkswagen           beetle  2015                          diesel
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_test
# Out:
#             make            model  year                engine_fuel_type  \
# 0           audi               q7  2014     premium_unleaded_(required)
# 1         toyota          sequoia  2017                regular_unleaded
# 2        lincoln              mkc  2015                regular_unleaded
# 3         nissan             370z  2015     premium_unleaded_(required)
# 4         toyota      prius_prime  2017                regular_unleaded
# ...          ...              ...   ...                             ...
# 2377         bmw               x6  2017     premium_unleaded_(required)
# 2378  volkswagen               cc  2017  premium_unleaded_(recommended)
# 2379   chevrolet          corsica  1996                regular_unleaded
# 2380       dodge  ram_pickup_1500  2008                regular_unleaded
# 2381  volkswagen           beetle  2015                          diesel
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
## Linear Regression

# %%
df_train.iloc[10]
# Out:
# make                                       infiniti
# model                                           q50
# year                                           2015
# engine_fuel_type     premium_unleaded_(recommended)
# engine_hp                                     328.0
# engine_cylinders                                6.0
# transmission_type                         automatic
# driven_wheels                      rear_wheel_drive
# number_of_doors                                 4.0
# market_category                  luxury,performance
# vehicle_size                                midsize
# vehicle_style                                 sedan
# highway_mpg                                      29
# city_mpg                                         20
# popularity                                      190
# Name: 10, dtype: object

# %%
def linear_regression(x):
    n = len(x)

    pred = w0

    for j in range(n):
        pred = pred + w[j] * x[j]
    return pred

# %%
x = [190, 14, 549]
w0 = 7.17
w = [ 0.02, 0.04, 0.005]

# %%
linear_regression(x)
# Out:
# 14.275000000000002

# %%
np.exp(14.665000000000001)
# Out:
# np.float64(2338452.631477475)

# %%
np.log1p(2338452.631477475)
# Out:
# np.float64(14.665000427633117)

# %%
### Linear_regression on vector form

# %%
def dot(x,w):
    n = len(x)

    pred = 0

    for j in range(n):
        pred = pred + x[j] * w[j]

    return pred

# %%
def linear_regression(x):
    return w0 + dot(x, w_new)

# %%
w_new = [w0] + w
w_new
# Out:
# [7.17, 0.02, 0.04, 0.005]

# %%
def linear_regression(x):
    x = [1] + x
    return dot(x,w_new)

# %%
linear_regression(x)
# Out:
# 14.275000000000002

# %%
df_train.iloc[[10, 7, 8]]
# Out:
#              make         model  year                engine_fuel_type  \
# 10       infiniti           q50  2015  premium_unleaded_(recommended)
# 7   mercedes-benz     gla-class  2015     premium_unleaded_(required)
# 8          suzuki  grand_vitara  2011                regular_unleaded
#
#     engine_hp  engine_cylinders transmission_type     driven_wheels  \
# 10      328.0               6.0         automatic  rear_wheel_drive
# 7       208.0               4.0  automated_manual   all_wheel_drive
# 8       166.0               4.0            manual  rear_wheel_drive
#
#     number_of_doors     market_category vehicle_size vehicle_style  \
# 10              4.0  luxury,performance      midsize         sedan
# 7               4.0    crossover,luxury      compact       4dr_suv
# 8               4.0           crossover      compact       4dr_suv
#
#     highway_mpg  city_mpg  popularity
# 10           29        20         190
# 7            32        24         617
# ...

# %%
x1= [ 6, 282, 17, 5657]
x2 = [6, 160, 18, 26]
x3 = [6, 148, 23, 640]

x = [x1, x2,x3]
x= np.array(x)

# %%
x
# Out:
# array([[   6,  282,   17, 5657],
#        [   6,  160,   18,   26],
#        [   6,  148,   23,  640]])

# %%
x.dot(w_new)
# Out:
# array([77.625, 47.07 , 50.1  ])

# %%
def linear_regression(x):
    return x.dot(w_new)

# %%
linear_regression(x)
# Out:
# array([77.625, 47.07 , 50.1  ])

# %%
## Training a linear regression model

# %%
 df_train.iloc[1:10]
# Out:
#             make         model  year                engine_fuel_type  \
# 1        bentley        arnage  2008     premium_unleaded_(required)
# 2     volkswagen        tiguan  2015  premium_unleaded_(recommended)
# 3      chevrolet      colorado  2012                regular_unleaded
# 4          tesla       model_s  2016                        electric
# 5           ford  e-series_van  2014        flex-fuel_(unleaded/e85)
# 6          mazda          cx-3  2016                regular_unleaded
# 7  mercedes-benz     gla-class  2015     premium_unleaded_(required)
# 8         suzuki  grand_vitara  2011                regular_unleaded
# 9          honda     crosstour  2015                regular_unleaded
#
#    engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 1      450.0               8.0         automatic   rear_wheel_drive
# 2      200.0               4.0         automatic  front_wheel_drive
# 3      185.0               4.0         automatic   four_wheel_drive
# ...

# %%
 df_train.iloc[1:10]
# Out:
#             make         model  year                engine_fuel_type  \
# 1        bentley        arnage  2008     premium_unleaded_(required)
# 2     volkswagen        tiguan  2015  premium_unleaded_(recommended)
# 3      chevrolet      colorado  2012                regular_unleaded
# 4          tesla       model_s  2016                        electric
# 5           ford  e-series_van  2014        flex-fuel_(unleaded/e85)
# 6          mazda          cx-3  2016                regular_unleaded
# 7  mercedes-benz     gla-class  2015     premium_unleaded_(required)
# 8         suzuki  grand_vitara  2011                regular_unleaded
# 9          honda     crosstour  2015                regular_unleaded
#
#    engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 1      450.0               8.0         automatic   rear_wheel_drive
# 2      200.0               4.0         automatic  front_wheel_drive
# 3      185.0               4.0         automatic   four_wheel_drive
# ...

# %%
def train_linear_regression(x,y):
    pass

# %%
x = ([[700, 11, 1158],
      [185, 27, 2202],
      [155, 17, 481],
      [381, 13, 2031],
      [275, 16, 1624],
      [297, 17, 190],
      [308, 16, 1624],
      [210, 25, 873],
      [230, 13, 1385]])

x = np.array(x)
x
# Out:
# array([[ 700,   11, 1158],
#        [ 185,   27, 2202],
#        [ 155,   17,  481],
#        [ 381,   13, 2031],
#        [ 275,   16, 1624],
#        [ 297,   17,  190],
#        [ 308,   16, 1624],
#        [ 210,   25,  873],
#        [ 230,   13, 1385]])

# %%
y = [200, 100, 150, 210, 410, 300, 270, 240, 180]
y
# Out:
# [200, 100, 150, 210, 410, 300, 270, 240, 180]

# %%
ones = np.ones(x.shape[0])
ones
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
x = np.column_stack([ones,x])
x
# Out:
# array([[1.000e+00, 7.000e+02, 1.100e+01, 1.158e+03],
#        [1.000e+00, 1.850e+02, 2.700e+01, 2.202e+03],
#        [1.000e+00, 1.550e+02, 1.700e+01, 4.810e+02],
#        [1.000e+00, 3.810e+02, 1.300e+01, 2.031e+03],
#        [1.000e+00, 2.750e+02, 1.600e+01, 1.624e+03],
#        [1.000e+00, 2.970e+02, 1.700e+01, 1.900e+02],
#        [1.000e+00, 3.080e+02, 1.600e+01, 1.624e+03],
#        [1.000e+00, 2.100e+02, 2.500e+01, 8.730e+02],
#        [1.000e+00, 2.300e+02, 1.300e+01, 1.385e+03]])

# %%
xtx = x.T.dot(x) ## gram matrix
xtx
# Out:
# array([[9.0000000e+00, 2.7410000e+03, 1.5500000e+02, 1.1568000e+04],
#        [2.7410000e+03, 1.0491090e+06, 4.2900000e+04, 3.5714380e+06],
#        [1.5500000e+02, 4.2900000e+04, 2.9030000e+03, 2.0180000e+05],
#        [1.1568000e+04, 3.5714380e+06, 2.0180000e+05, 1.8537296e+07]])

# %%
xtx_inv = np.linalg.pinv(xtx)
xtx_inv
# Out:
# array([[ 4.36887682e+00, -4.48048378e-03, -1.54329790e-01,
#         -1.83071216e-04],
#        [-4.48048378e-03,  7.55234454e-06,  1.41433664e-04,
#         -1.98724094e-07],
#        [-1.54329790e-01,  1.41433664e-04,  6.96363099e-03,
#         -6.74830255e-06],
#        [-1.83071216e-04, -1.98724094e-07, -6.74830255e-06,
#          2.79938674e-07]])

# %%
w_full = xtx_inv.dot(x.T).dot(y)
w_full
# Out:
# array([ 3.43803085e+02, -3.84746743e-02, -4.70599055e+00, -1.72320322e-02])

# %%
w0 = w_full[0]
w = w_full[1:]

w0, w
# Out:
# (np.float64(343.8030851374875), array([-0.03847467, -4.70599055, -0.01723203]))

# %%
def train_linear_regression(x,y):
    ones = np.ones(x.shape[0])
    x = np.column_stack([ones,x])

    xtx = x.T.dot(x)
    xtx_inv = np.linalg.pinv(xtx)
    w_full = xtx_inv.dot(x.T).dot(y)

    return w_full[0], w_full[1:]

# %%
train_linear_regression(x,y)
# Out:
# (np.float64(171.90154255425642),
#  array([ 1.71901543e+02, -3.84746742e-02, -4.70599055e+00, -1.72320322e-02]))

# %%
def train_linear_regression(x,y):
    ones = np.ones(x.shape[0])
    x = np.column_stack([ones,x])

    xtx = x.T.dot(x)
    xtx_inv = np.linalg.pinv(xtx)
    w_full = xtx_inv.dot(x.T).dot(y)

    return w_full[0], w_full[1:]

# %%
train_linear_regression(x,y)
# Out:
# (np.float64(171.90154255425642),
#  array([ 1.71901543e+02, -3.84746742e-02, -4.70599055e+00, -1.72320322e-02]))

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
## Car price baseline model

# %%
base = ["engine_hp", "engine_cylinders", "highway_mpg", "city_mpg", "popularity"]
base
# Out:
# ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
df_train[base]
# Out:
#       engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         170.0               4.0           38        25         873
# 1         450.0               8.0           15         9         520
# 2         200.0               4.0           26        21         873
# 3         185.0               4.0           23        17        1385
# 4           NaN               0.0          105       102        1391
# ...         ...               ...          ...       ...         ...
# 7145      255.0               8.0           16        12        5657
# 7146      159.0               4.0           24        19        2031
# 7147      200.0               6.0           21        15         210
# 7148      210.0               4.0           29        23         873
# 7149      460.0               8.0           25        16        1385
#
# [7150 rows x 5 columns]

# %%
x_train = df_train[base].values

# %%
y_train
# Out:
# array([10.44205479, 12.48367029, 10.35012659, ..., 10.22922379,
#        10.32535081, 11.14837675])

# %%
df_train[base].isnull().sum()
# Out:
# engine_hp           41
# engine_cylinders    20
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
x_train = df_train[base].fillna(0).values
x_train
# Out:
# array([[ 170.,    4.,   38.,   25.,  873.],
#        [ 450.,    8.,   15.,    9.,  520.],
#        [ 200.,    4.,   26.,   21.,  873.],
#        ...,
#        [ 200.,    6.,   21.,   15.,  210.],
#        [ 210.,    4.,   29.,   23.,  873.],
#        [ 460.,    8.,   25.,   16., 1385.]])

# %%
w0, w = train_linear_regression(x_train, y_train)

# %%
y_pred =  w0 + x_train.dot(w)
y_pred
# Out:
# array([10.05591155, 11.28768016,  9.81753832, ...,  9.41771794,
#        10.02872693, 11.7611784 ])

# %%
sns.histplot(y_pred, color = "red", bins = 50, alpha= 0.5)
sns.histplot(y_train, color = "green", bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
## Root mean square (Evaluating linear regression model)

# %%
def rmse(y, y_pred):
    error = y - y_pred
    se = error **2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# np.float64(0.7536376580605106)

# %%
## computing rmse on validation data

# %%
 def prepare_x(df):
     df_num = df[base]
     df_num = df_num.fillna(0)
     x  = df_num.values
     return x

# %%
x_train = prepare_x(df_train)
w0, w = train_linear_regression(x_train, y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.782362163669826)

# %%
## simple feature Engineering

# %%
def prepare_x(df):
    df = df.copy()
    df["age"] = 2017 - df.year
    features = base + ["age"]
    df_num = df[features]
    df_num = df_num.fillna(0)
    x = df_num.values
    return x

# %%
x_train = prepare_x(df_train)
w0, w = train_linear_regression(x_train, y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5070402525401033)

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
sns.histplot(y_val, color = "red", bins = 50, alpha = 0.5)
sns.histplot(y_pred, color = "yellow", bins = 50, alpha = 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
## Categorical variables

# %%
df_train
# Out:
#             make               model  year                engine_fuel_type  \
# 0     volkswagen              passat  2016                regular_unleaded
# 1        bentley              arnage  2008     premium_unleaded_(required)
# 2     volkswagen              tiguan  2015  premium_unleaded_(recommended)
# 3      chevrolet            colorado  2012                regular_unleaded
# 4          tesla             model_s  2016                        electric
# ...          ...                 ...   ...                             ...
# 7145        ford        e-series_van  2012        flex-fuel_(unleaded/e85)
# 7146      toyota              tacoma  2015                regular_unleaded
# 7147     pontiac             montana  2005                regular_unleaded
# 7148  volkswagen  beetle_convertible  2014  premium_unleaded_(recommended)
# 7149   chevrolet            corvette  2017  premium_unleaded_(recommended)
#
# ...

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
df_train.number_of_doors
# Out:
# 0       4.0
# 1       4.0
# 2       4.0
# 3       4.0
# 4       NaN
#        ...
# 7145    3.0
# 7146    4.0
# 7147    4.0
# 7148    2.0
# 7149    2.0
# Name: number_of_doors, Length: 7150, dtype: float64

# %%
df_train.number_of_doors ==2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7145    False
# 7146    False
# 7147    False
# 7148     True
# 7149     True
# Name: number_of_doors, Length: 7150, dtype: bool

# %%
df.make.value_counts()
# Out:
# make
# chevrolet        1123
# ford              881
# volkswagen        809
# toyota            746
# dodge             626
# nissan            558
# gmc               515
# honda             449
# mazda             423
# cadillac          397
# mercedes-benz     353
# suzuki            351
# bmw               334
# infiniti          330
# audi              328
# hyundai           303
# volvo             281
# subaru            256
# acura             252
# kia               231
# mitsubishi        213
# lexus             202
# buick             196
# chrysler          187
# pontiac           186
# lincoln           164
# oldsmobile        150
# land_rover        143
# porsche           136
# saab              111
# aston_martin       93
# plymouth           82
# bentley            74
# ferrari            69
# fiat               62
# scion              60
# maserati           58
# lamborghini        52
# rolls-royce        31
# lotus              29
# tesla              18
# ...

# %%
list(df.make.value_counts().head().index)
# Out:
# ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']

# %%
for v in [2, 3, 4]:
    df_train["num_doors_%s" %v] = (df_train.number_of_doors == v).astype("int")

# %% [markdown]
# # Assistant
# This error occurs because of inconsistent indentation in your code. Python uses indentation to define code blocks, and the error is telling you that the indentation at line 9 doesn't match any outer indentation level.
#
# Would you like me to provide the corrected code?

# %%
def prepare_x(df):
    df = df.copy()

    df["age"] = 2017 - df.year
    features = base.copy()
    features.append("age")

    # Fixed indentation here - was previously misaligned
    for v in [2,3,4]:
        # Fixed string formatting syntax - was using incorrect comma
        df["num_doors_%s" % v] = (df.number_of_doors == v).astype("int")
        features.append("num_doors_%s" % v)

    df_num = df[features]
    df_num = df_num.fillna(0)
    x = df_num.values

    return x

# %%
prepare_x(df_train)
# Out:
# array([[170.,   4.,  38., ...,   0.,   0.,   1.],
#        [450.,   8.,  15., ...,   0.,   0.,   1.],
#        [200.,   4.,  26., ...,   0.,   0.,   1.],
#        ...,
#        [200.,   6.,  21., ...,   0.,   0.,   1.],
#        [210.,   4.,  29., ...,   1.,   0.,   0.],
#        [460.,   8.,  25., ...,   1.,   0.,   0.]])

# %%
x_train = prepare_x(df_train)
w0, w = train_linear_regression(x_train, y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5113406351409752)

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# num_doors_2            int64
# num_doors_3            int64
# num_doors_4            int64
# dtype: object

# %%
df.make.nunique()
# Out:
# 48

# %%
df.make.value_counts().head()
# Out:
# make
# chevrolet     1123
# ford           881
# volkswagen     809
# toyota         746
# dodge          626
# Name: count, dtype: int64

# %%
make = list(df.make.value_counts().head().index)
make
# Out:
# ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']

# %%
make = list(df.make.value_counts().head().index)
make
# Out:
# ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']

# %%
def prepare_x(df):
    df = df.copy()

    df["age"] = 2017 - df.year
    features = base.copy()
    features.append("age")

    # Fixed indentation here - was previously misaligned
    for v in [2,3,4]:
        # Fixed string formatting syntax - was using incorrect comma
        df["num_doors_%s" % v] = (df.number_of_doors == v).astype("int")
        features.append("num_doors_%s" % v)
    for v in make:
        df["make %s" % v] = (df.make == v).astype("int")
        features.append("make %s" % v)

    df_num = df[features]
    df_num = df_num.fillna(0)
    x = df_num.values

    return x

# %%
x_train = prepare_x(df_train)
w0, w = train_linear_regression(x_train, y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5154447605903261)

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# num_doors_2            int64
# num_doors_3            int64
# num_doors_4            int64
# dtype: object

# %%
Categories_variables = ["make", "engine_fuel_type", "transmission_type", "driven_wheels", "market_category", "vehicle_size", "vehicle_style"]

# %%
Categories = {}

for c in Categories_variables:
    Categories[c] = list(df[c].value_counts().head().index)

# %%
Categories
# Out:
# {'make': ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge'],
#  'engine_fuel_type': ['regular_unleaded',
#   'premium_unleaded_(required)',
#   'premium_unleaded_(recommended)',
#   'flex-fuel_(unleaded/e85)',
#   'diesel'],
#  'transmission_type': ['automatic',
#   'manual',
#   'automated_manual',
#   'direct_drive',
#   'unknown'],
#  'driven_wheels': ['front_wheel_drive',
#   'rear_wheel_drive',
#   'all_wheel_drive',
#   'four_wheel_drive'],
#  'market_category': ['crossover',
#   'flex_fuel',
#   'luxury',
#   'luxury,performance',
#   'hatchback'],
#  'vehicle_size': ['compact', 'midsize', 'large'],
#  'vehicle_style': ['sedan',
#   '4dr_suv',
#   'coupe',
#   'convertible',
#   '4dr_hatchback']}

# %%
def prepare_x(df):
    df = df.copy()

    df["age"] = 2017 - df.year
    features = base.copy()
    features.append("age")

    # Fixed indentation here - was previously misaligned
    for v in [2,3,4]:
        # Fixed string formatting syntax - was using incorrect comma
        df["num_doors_%s" % v] = (df.number_of_doors == v).astype("int")
        features.append("num_doors_%s" % v)
    
    # Fixed indentation - this was causing the error
    for c, values in Categories.items():
        for v in make:
            df["make %s" % v] = (df.make == v).astype("int")
            features.append("make %s" % v)

    df_num = df[features]
    df_num = df_num.fillna(0)
    x = df_num.values

    return x

# %%
x_train = prepare_x(df_train)
w0, w = train_linear_regression(x_train, y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5154447594852976)

# %%
w0
# Out:
# np.float64(10.840685508599307)

# %%
w
# Out:
# array([ 3.38260801e-03,  7.84538169e-02, -2.23982569e-02,  2.43452827e-02,
#        -2.51510234e-05, -9.67036616e-02, -1.11850132e+00, -1.42398857e+00,
#        -1.16125460e+00, -2.68221678e-02, -1.61196817e-02,  5.26193327e-03,
#        -4.24794876e-02, -3.84050210e-02, -2.68221678e-02, -1.61196817e-02,
#         5.26193327e-03, -4.24794876e-02, -3.84050210e-02, -2.68221678e-02,
#        -1.61196817e-02,  5.26193327e-03, -4.24794876e-02, -3.84050210e-02,
#        -2.68221678e-02, -1.61196817e-02,  5.26193327e-03, -4.24794876e-02,
#        -3.84050210e-02, -2.68221678e-02, -1.61196817e-02,  5.26193327e-03,
#        -4.24794876e-02, -3.84050210e-02, -2.68221678e-02, -1.61196817e-02,
#         5.26193327e-03, -4.24794876e-02, -3.84050210e-02, -2.68221678e-02,
#        -1.61196817e-02,  5.26193327e-03, -4.24794876e-02, -3.84050210e-02])

# %%
## Regularisation

# %%
x = [ 
    [4,4,4],
    [3,5,5],
    [4,7,8],
    [2,5,9],
    [3,9,7],
    [2,7,0],
]

x = np.array(x)
x
# Out:
# array([[4, 4, 4],
#        [3, 5, 5],
#        [4, 7, 8],
#        [2, 5, 9],
#        [3, 9, 7],
#        [2, 7, 0]])

# %%
xtx = x.T.dot(x)
xtx
# Out:
# array([[ 58, 110, 102],
#        [110, 245, 205],
#        [102, 205, 235]])

# %%
xtx_inv = np.linalg.inv(xtx)
xtx_inv
# Out:
# array([[ 0.14185368, -0.04506477, -0.02225871],
#        [-0.04506477,  0.02942894, -0.00611202],
#        [-0.02225871, -0.00611202,  0.01924831]])

# %%
y = [3,7,8, 5, 8, 2]
y
# Out:
# [3, 7, 8, 5, 8, 2]

# %%
 w_full = xtx_inv.dot(x.T).dot(y)

# %%
w_full
# Out:
# array([0.24822113, 0.36037219, 0.48002189])

# %%
xtx = [
    [1.000,2,3],
    [2,1.000,1.000],
    [2,1,1.0001]
]

# %%
np.linalg.inv(xtx)
# Out:
# array([[-3.33333333e-01, -3.33266667e+03,  3.33333333e+03],
#        [ 6.66666667e-01,  1.66663333e+04, -1.66666667e+04],
#        [ 0.00000000e+00, -1.00000000e+04,  1.00000000e+04]])

# %%
xtx = xtx + 0.01 * np.eye(3)
xtx
# Out:
# array([[1.01  , 2.    , 3.    ],
#        [2.    , 1.01  , 1.    ],
#        [2.    , 1.    , 1.0101]])

# %%
np.linalg.inv(xtx)
# Out:
# array([[ -0.252522  , -12.24796083,  12.87548444],
#        [  0.2525095 ,  62.24982965, -62.37734695],
#        [  0.25000941, -37.37640629,  37.25015154]])

# %%
def train_linear_regression_reg(x,y, r =0.01):
    ones = np.ones(x.shape[0])
    x = np.column_stack([ones,x])

    xtx = x.T.dot(x)
    xtx = xtx + 0.01 * np.eye(xtx.shape[0])
    
    xtx_inv = np.linalg.pinv(xtx)
    w_full = xtx_inv.dot(x.T).dot.(y)

    return w_full[0], w_full[1:]

# %%
x_train = prepare_x(df_train)
w0, w = train_linear_regression_reg(x_train, y_train, r= 0.01)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val, y_pred)
# Out:
# np.float64(0.5153406911551125)

# %%
## Tuning the model

# %%
for r in [0.0, 0.00001, 0.001, 0.01, 0.1, 1, 10]:
    x_train = prepare_x(df_train)
    w0, w = train_linear_regression_reg(x_train, y_train, r=r)

    x_val = prepare_x(df_val)
    y_pred = w0 + x_val.dot(w)
    score = rmse(y_val, y_pred)
    print(r, w0, score)
# Out:
# 0.0 10.788400089317598 0.5153406911551125
# 1e-05 10.788400089317598 0.5153406911551125
# 0.001 10.788400089317598 0.5153406911551125
# 0.01 10.788400089317598 0.5153406911551125
# 0.1 10.788400089317598 0.5153406911551125
# 1 10.788400089317598 0.5153406911551125
# 10 10.788400089317598 0.5153406911551125

# %%
r = 0.001
x_train = prepare_x(df_train)
w0, w = train_linear_regression_reg(x_train, y_train, r=r)
x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)
score = rmse(y_val, y_pred)   
print(score)
# Out:
# 0.5153406911551125

# %%
 ## using the model

# %%
df_full_train = pd.concat([df_train, df_val])

# %%
df_full_train
# Out:
#             make            model  year                engine_fuel_type  \
# 0     volkswagen           passat  2016                regular_unleaded
# 1        bentley           arnage  2008     premium_unleaded_(required)
# 2     volkswagen           tiguan  2015  premium_unleaded_(recommended)
# 3      chevrolet         colorado  2012                regular_unleaded
# 4          tesla          model_s  2016                        electric
# ...          ...              ...   ...                             ...
# 2377         bmw               x6  2017     premium_unleaded_(required)
# 2378  volkswagen               cc  2017  premium_unleaded_(recommended)
# 2379   chevrolet          corsica  1996                regular_unleaded
# 2380       dodge  ram_pickup_1500  2008                regular_unleaded
# 2381  volkswagen           beetle  2015                          diesel
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_full_train = df_full_train.reset_index(drop=True)
df_full_train
# Out:
#             make            model  year                engine_fuel_type  \
# 0     volkswagen           passat  2016                regular_unleaded
# 1        bentley           arnage  2008     premium_unleaded_(required)
# 2     volkswagen           tiguan  2015  premium_unleaded_(recommended)
# 3      chevrolet         colorado  2012                regular_unleaded
# 4          tesla          model_s  2016                        electric
# ...          ...              ...   ...                             ...
# 9527         bmw               x6  2017     premium_unleaded_(required)
# 9528  volkswagen               cc  2017  premium_unleaded_(recommended)
# 9529   chevrolet          corsica  1996                regular_unleaded
# 9530       dodge  ram_pickup_1500  2008                regular_unleaded
# 9531  volkswagen           beetle  2015                          diesel
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
x_full_train = prepare_x(df_full_train)
x_full_train
# Out:
# array([[170.,   4.,  38., ...,   1.,   0.,   0.],
#        [450.,   8.,  15., ...,   0.,   0.,   0.],
#        [200.,   4.,  26., ...,   1.,   0.,   0.],
#        ...,
#        [120.,   4.,  29., ...,   0.,   0.,   0.],
#        [310.,   8.,  16., ...,   0.,   0.,   1.],
#        [150.,   4.,  41., ...,   1.,   0.,   0.]])

# %%
y_full_train = np.concatenate([y_train, y_pred])

# %%
y_full_train
# Out:
# array([10.44205479, 12.48367029, 10.35012659, ...,  8.00761928,
#        10.14624925, 10.20152704])

# %%
w0, w = train_linear_regression_reg(x_full_train, y_full_train, r = 0.0001)

# %%
x_test = prepare_x(df_test)
y_pred = w0 + x_val.dot(w)
score = rmse(y_val, y_pred)
score
# Out:
# np.float64(0.5153406905889317)

# %%
 df_test.iloc[20]
# Out:
# make                                    buick
# model                                lacrosse
# year                                     2016
# engine_fuel_type     flex-fuel_(unleaded/e85)
# engine_hp                               304.0
# engine_cylinders                          6.0
# transmission_type                   automatic
# driven_wheels               front_wheel_drive
# number_of_doors                           4.0
# market_category         flex_fuel,performance
# vehicle_size                            large
# vehicle_style                           sedan
# highway_mpg                                28
# city_mpg                                   18
# popularity                                155
# Name: 20, dtype: object

# %%
 vehicle = df_test.iloc[20].to_dict()

# %%
vehicle
# Out:
# {'make': 'buick',
#  'model': 'lacrosse',
#  'year': 2016,
#  'engine_fuel_type': 'flex-fuel_(unleaded/e85)',
#  'engine_hp': 304.0,
#  'engine_cylinders': 6.0,
#  'transmission_type': 'automatic',
#  'driven_wheels': 'front_wheel_drive',
#  'number_of_doors': 4.0,
#  'market_category': 'flex_fuel,performance',
#  'vehicle_size': 'large',
#  'vehicle_style': 'sedan',
#  'highway_mpg': 28,
#  'city_mpg': 18,
#  'popularity': 155}

# %%
df_small = pd.DataFrame([vehicle])
df_small
# Out:
#     make     model  year          engine_fuel_type  engine_hp  \
# 0  buick  lacrosse  2016  flex-fuel_(unleaded/e85)      304.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               6.0         automatic  front_wheel_drive              4.0
#
#          market_category vehicle_size vehicle_style  highway_mpg  city_mpg  \
# 0  flex_fuel,performance        large         sedan           28        18
#
#    popularity
# 0         155

# %%
x_small = prepare_x(df_small)

# %%
y_pred = w0 + x_small.dot(w)
y_pred = y_pred[0]
y_pred
# Out:
# np.float64(10.889053827472575)

# %%
np.log(10.889053827472575)-1
# Out:
# np.float64(1.387758048640582)

# %%
np.expm1(y_pred)
# Out:
# np.float64(53585.573832002556)

# %%
y_test[20]
# Out:
# np.float64(10.5506169722625)

# %%
np.expm1(y_test[20])
# Out:
# np.float64(38200.0)
