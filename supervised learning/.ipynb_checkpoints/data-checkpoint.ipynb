# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression,Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mutual_info_score,mean_squared_error

# %%
df = pd.read_csv("data.csv")
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
strings = list(df.dtypes[df.dtypes == "object"].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace( ' ', '_')
    df

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
column = ['make', 'model', 'year',  'engine_hp',
       'engine_cylinders', 'transmission_type',  'vehicle_style','highway_mpg',
'city_mpg', 'popularity', 'msrp']

# %%
  df = df[column]

# %%
df.isnull().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# popularity            0
# msrp                  0
# dtype: int64

# %%
df.fillna(0)
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          bmw  1_series_m  2011      335.0               6.0
# 1          bmw    1_series  2011      300.0               6.0
# 2          bmw    1_series  2011      300.0               6.0
# 3          bmw    1_series  2011      230.0               6.0
# 4          bmw    1_series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    acura         zdx  2012      300.0               6.0
# 11910    acura         zdx  2012      300.0               6.0
# 11911    acura         zdx  2012      300.0               6.0
# 11912    acura         zdx  2013      300.0               6.0
# 11913  lincoln      zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  popularity  \
# 0                manual          coupe           26        19        3916
# ...

# %%
df.isnull().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# popularity            0
# msrp                  0
# dtype: int64

# %%
df.engine_hp = df.engine_hp.fillna(0)
df.engine_hp
# Out:
# C:\Users\ACE\AppData\Local\Temp\ipykernel_15340\547604790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.engine_hp = df.engine_hp.fillna(0)
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: engine_hp, Length: 11914, dtype: float64

# %%
df.engine_cylinders = df.engine_cylinders.fillna(0)
df.engine_cylinders
# Out:
# C:\Users\ACE\AppData\Local\Temp\ipykernel_15340\294037318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.engine_cylinders = df.engine_cylinders.fillna(0)
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: engine_cylinders, Length: 11914, dtype: float64

# %%
df.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# popularity           0
# msrp                 0
# dtype: int64

# %%
df= df.rename(columns = {"msrp":"price"})
df
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          bmw  1_series_m  2011      335.0               6.0
# 1          bmw    1_series  2011      300.0               6.0
# 2          bmw    1_series  2011      300.0               6.0
# 3          bmw    1_series  2011      230.0               6.0
# 4          bmw    1_series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    acura         zdx  2012      300.0               6.0
# 11910    acura         zdx  2012      300.0               6.0
# 11911    acura         zdx  2012      300.0               6.0
# 11912    acura         zdx  2013      300.0               6.0
# 11913  lincoln      zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  popularity  \
# 0                manual          coupe           26        19        3916
# ...

# %%
df.transmission_type.mode()
# Out:
# 0    automatic
# Name: transmission_type, dtype: object

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# price                  int64
# dtype: object

# %%
numerical_variables = ["year", "engine_hp", "engine_cylinders", "highway_mpg", "city_mpg", "popularity"]
numerical_variables
# Out:
# ['year',
#  'engine_hp',
#  'engine_cylinders',
#  'highway_mpg',
#  'city_mpg',
#  'popularity']

# %%
df[numerical_variables].corrwith(df.price)
# Out:
# year                0.227590
# engine_hp           0.650095
# engine_cylinders    0.526274
# highway_mpg        -0.160043
# city_mpg           -0.157676
# popularity         -0.048476
# dtype: float64

# %%
df[numerical_variables].corrwith(df.price).sort_values(ascending = False)
# Out:
# engine_hp           0.650095
# engine_cylinders    0.526274
# year                0.227590
# popularity         -0.048476
# city_mpg           -0.157676
# highway_mpg        -0.160043
# dtype: float64

# %%
df.price
# Out:
# 0        46135
# 1        40650
# 2        36350
# 3        29450
# 4        34500
#          ...
# 11909    46120
# 11910    56670
# 11911    50620
# 11912    50920
# 11913    28995
# Name: price, Length: 11914, dtype: int64

# %%
df.price.mean()
# Out:
# np.float64(40594.737032063116)

# %%
df = df.copy()
mean = df["price"].mean()

df["average_price"] = np.where(df["price"]>=mean, 1, 0)

# %%
df = df.drop(["price"], axis = 1)
df
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          bmw  1_series_m  2011      335.0               6.0
# 1          bmw    1_series  2011      300.0               6.0
# 2          bmw    1_series  2011      300.0               6.0
# 3          bmw    1_series  2011      230.0               6.0
# 4          bmw    1_series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    acura         zdx  2012      300.0               6.0
# 11910    acura         zdx  2012      300.0               6.0
# 11911    acura         zdx  2012      300.0               6.0
# 11912    acura         zdx  2013      300.0               6.0
# 11913  lincoln      zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  popularity  \
# 0                manual          coupe           26        19        3916
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df[numerical_variables].corr(), annot = True)
# Out:
# <Axes: >

# %%
 seed =np.random.seed(42)

# %%
df_full_train, df_test = train_test_split(df, test_size = 0.2, random_state = seed)
len(df_full_train), len(df_test)
# Out:
# (9531, 2383)

# %%
df_train, df_val = train_test_split(df_full_train, test_size = 0.25, random_state = 1)
len(df_train), len(df_test), len(df_val)
# Out:
# (7148, 2383, 2383)

# %%
df_train = df_train.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)

# %%
y_train = df_train.average_price.values
y_val = df_val.average_price.values
y_test = df_test.average_price.values

# %%
del df_train["average_price"]
del df_val["average_price"]
del df_test["average_price"]

# %%
from sklearn.metrics import mutual_info_score

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# average_price          int64
# dtype: object

# %%
categorical_variables = df.select_dtypes(include = ["object"])
categorical_variables
# Out:
#           make       model transmission_type  vehicle_style
# 0          bmw  1_series_m            manual          coupe
# 1          bmw    1_series            manual    convertible
# 2          bmw    1_series            manual          coupe
# 3          bmw    1_series            manual          coupe
# 4          bmw    1_series            manual    convertible
# ...        ...         ...               ...            ...
# 11909    acura         zdx         automatic  4dr_hatchback
# 11910    acura         zdx         automatic  4dr_hatchback
# 11911    acura         zdx         automatic  4dr_hatchback
# 11912    acura         zdx         automatic  4dr_hatchback
# 11913  lincoln      zephyr         automatic          sedan
#
# [11914 rows x 4 columns]

# %%
categorical_variables.columns
# Out:
# Index(['make', 'model', 'transmission_type', 'vehicle_style'], dtype='object')

# %%
mutual_info_score(df_full_train.model, df_full_train.average_price)
# Out:
# np.float64(0.46099440756035703)

# %%
mutual_info_score(df_full_train.transmission_type, df_full_train.average_price)
# Out:
# np.float64(0.020883575914971135)

# %%
def mutual_inf_score(series):
    return mutual_info_score(series, df_full_train.average_price)

# %%
categorical_variables = ["make", "model", "transmission_type", "vehicle_style"]
categorical_variables
# Out:
# ['make', 'model', 'transmission_type', 'vehicle_style']

# %%
x = df_full_train[categorical_variables].apply(mutual_inf_score)
x
# Out:
# make                 0.238724
# model                0.460994
# transmission_type    0.020884
# vehicle_style        0.083390
# dtype: float64

# %%
x = x.sort_values(ascending = False)
x
# Out:
# model                0.460994
# make                 0.238724
# vehicle_style        0.083390
# transmission_type    0.020884
# dtype: float64

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer(sparse = False)

# %%
dict_train = df_train[categorical_variables + numerical_variables].to_dict(orient = "records")

# %%
X_train = dv.fit_transform(dict_train)
X_train
# Out:
# array([[1.300e+01, 8.000e+00, 3.810e+02, ..., 0.000e+00, 0.000e+00,
#         2.016e+03],
#        [2.600e+01, 4.000e+00, 1.700e+02, ..., 0.000e+00, 0.000e+00,
#         2.016e+03],
#        [1.500e+01, 6.000e+00, 2.810e+02, ..., 0.000e+00, 0.000e+00,
#         2.016e+03],
#        ...,
#        [1.700e+01, 6.000e+00, 3.050e+02, ..., 0.000e+00, 0.000e+00,
#         2.015e+03],
#        [9.000e+00, 1.200e+01, 5.150e+02, ..., 0.000e+00, 0.000e+00,
#         2.003e+03],
#        [2.100e+01, 4.000e+00, 1.800e+02, ..., 1.000e+00, 0.000e+00,
#         1.991e+03]])

# %%
dict_val = df_val[categorical_variables + numerical_variables].to_dict(orient = "records")
X_val = dv.transform(dict_val)
X_val
# Out:
# array([[1.500e+01, 6.000e+00, 2.810e+02, ..., 0.000e+00, 0.000e+00,
#         2.017e+03],
#        [1.400e+01, 6.000e+00, 2.750e+02, ..., 0.000e+00, 0.000e+00,
#         2.015e+03],
#        [1.900e+01, 6.000e+00, 2.800e+02, ..., 1.000e+00, 0.000e+00,
#         2.013e+03],
#        ...,
#        [3.100e+01, 4.000e+00, 1.740e+02, ..., 0.000e+00, 0.000e+00,
#         2.016e+03],
#        [1.500e+01, 4.000e+00, 1.610e+02, ..., 0.000e+00, 0.000e+00,
#         1.997e+03],
#        [2.500e+01, 4.000e+00, 1.480e+02, ..., 0.000e+00, 0.000e+00,
#         2.015e+03]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver = "liblinear", C = 10, max_iter = 1000, random_state = 42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, random_state=42, solver='liblinear')

# %%
w = model.intercept_[0]

# %%
w
# Out:
# np.float64(-0.07738312967849666)

# %%
y_pred = model.predict_proba(X_val)[:,1]

# %%
y_pred
# Out:
# array([0.21175281, 0.12486414, 0.5878086 , ..., 0.00876759, 0.00363436,
#        0.0126701 ])

# %%
price_decision = y_pred > 0.5
price_decision
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
accuracy = (y_val == price_decision).mean()
accuracy
# Out:
# np.float64(0.9244649601342845)

# %%
dv.get_feature_names_out()
# Out:
# array(['city_mpg', 'engine_cylinders', 'engine_hp', 'highway_mpg',
#        'make=acura', 'make=alfa_romeo', 'make=aston_martin', 'make=audi',
#        'make=bentley', 'make=bmw', 'make=bugatti', 'make=buick',
#        'make=cadillac', 'make=chevrolet', 'make=chrysler', 'make=dodge',
#        'make=ferrari', 'make=fiat', 'make=ford', 'make=genesis',
#        'make=gmc', 'make=honda', 'make=hummer', 'make=hyundai',
#        'make=infiniti', 'make=kia', 'make=lamborghini', 'make=land_rover',
#        'make=lexus', 'make=lincoln', 'make=lotus', 'make=maserati',
#        'make=maybach', 'make=mazda', 'make=mclaren', 'make=mercedes-benz',
#        'make=mitsubishi', 'make=nissan', 'make=oldsmobile',
#        'make=plymouth', 'make=pontiac', 'make=porsche',
#        'make=rolls-royce', 'make=saab', 'make=scion', 'make=spyker',
#        'make=subaru', 'make=suzuki', 'make=tesla', 'make=toyota',
#        'make=volkswagen', 'make=volvo', 'model=100', 'model=124_spider',
# ...

# %%
list(zip(dv.get_feature_names_out(), model.coef_[0].round(3)))
# Out:
# [('city_mpg', np.float64(-0.014)),
#  ('engine_cylinders', np.float64(0.043)),
#  ('engine_hp', np.float64(0.033)),
#  ('highway_mpg', np.float64(0.125)),
#  ('make=acura', np.float64(1.035)),
#  ('make=alfa_romeo', np.float64(0.408)),
#  ('make=aston_martin', np.float64(0.172)),
#  ('make=audi', np.float64(2.128)),
#  ('make=bentley', np.float64(0.077)),
#  ('make=bmw', np.float64(2.114)),
#  ('make=bugatti', np.float64(0.0)),
#  ('make=buick', np.float64(-0.754)),
#  ('make=cadillac', np.float64(2.003)),
#  ('make=chevrolet', np.float64(-1.344)),
#  ('make=chrysler', np.float64(-1.127)),
#  ('make=dodge', np.float64(-2.758)),
#  ('make=ferrari', np.float64(0.246)),
#  ('make=fiat', np.float64(-0.165)),
#  ('make=ford', np.float64(-0.786)),
#  ('make=genesis', np.float64(0.139)),
#  ('make=gmc', np.float64(-0.872)),
#  ('make=honda', np.float64(-1.391)),
#  ('make=hummer', np.float64(0.055)),
#  ('make=hyundai', np.float64(-1.986)),
#  ('make=infiniti', np.float64(0.166)),
# ...

# %%
features = df_train.columns.to_list()
features
# Out:
# ['make',
#  'model',
#  'year',
#  'engine_hp',
#  'engine_cylinders',
#  'transmission_type',
#  'vehicle_style',
#  'highway_mpg',
#  'city_mpg',
#  'popularity']

# %%
from sklearn.metrics import accuracy_score

# %%
original_score = accuracy
scores = pd.DataFrame(columns=['eliminated_feature', 'accuracy', 'difference'])
for feature in features:
    subset = features.copy()
    subset.remove(feature)
    
    dv = DictVectorizer(sparse=False)
    train_dict = df_train[subset].to_dict(orient='records')
    X_train = dv.fit_transform(train_dict)

    model = LogisticRegression(solver='liblinear', max_iter=1000, C=10, random_state=seed)
    model.fit(X_train, y_train)
    
    val_dict = df_val[subset].to_dict(orient='records')
    X_val = dv.transform(val_dict)
    
    y_pred = model.predict(X_val)
    score = accuracy_score(y_val, y_pred)
    
    scores.loc[len(scores)] = [feature, score, original_score - score]

# %%
score
# Out:
# 0.9215274863617289

# %%
scores
# Out:
#   eliminated_feature  accuracy  difference
# 0               make  0.935795   -0.011330
# 1              model  0.910617    0.013848
# 2               year  0.933277   -0.008812
# 3          engine_hp  0.930340   -0.005875
# 4   engine_cylinders  0.921527    0.002937
# 5  transmission_type  0.916072    0.008393
# 6      vehicle_style  0.935795   -0.011330
# 7        highway_mpg  0.938313   -0.013848
# 8           city_mpg  0.943768   -0.019303
# 9         popularity  0.921527    0.002937

# %%
cores = {}
for alpha in [0, 0.01, 0.1, 1, 10]:
    model = Ridge(alpha=alpha, solver='sag', random_state=seed)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_val)
    
    score = mean_squared_error(y_val, y_pred)
    scores[alpha] = round(score, 3)
    print(f'alpha = {alpha}:\t RMSE = {score}')
# Out:
# C:\Users\ACE\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# alpha = 0:	 RMSE = 0.09285592025858308
# C:\Users\ACE\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# alpha = 0.01:	 RMSE = 0.09285608095006345
# C:\Users\ACE\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# alpha = 0.1:	 RMSE = 0.09285773686589685
# C:\Users\ACE\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# alpha = 1:	 RMSE = 0.09286758791409484
# alpha = 10:	 RMSE = 0.09295550543183992
# ...

# %%
scores
# Out:
# {0: np.float64(0.305),
#  0.01: np.float64(0.305),
#  0.1: np.float64(0.305),
#  1: np.float64(0.305),
#  10: np.float64(0.305)}
